# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\SUJAY GADE\OneDrive\Desktop\DEEP LEARNING\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
sent_length = 8
one_hot_repr = [one_hot(words, voc_size) for words in sent]
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)
print(embedded_docs)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3964 5039 9438 2955]
#  [   0    0    0    0 3964 5039 9438 3461]
#  [   0    0    0    0 3964 3593 9438 4637]
#  [   0    0    0 8028 3864 7879 2132 6033]
#  [   0    0    0 8028 3864 7879 2132 8301]
#  [   0    0    0 7600 3964 3987 9438  176]
#  [   0    0    0    0 6551 1419  170 2132]]
# [[   0    0    0    0 3964 5039 9438 2955]
#  [   0    0    0    0 3964 5039 9438 3461]
#  [   0    0    0    0 3964 3593 9438 4637]
#  [   0    0    0 8028 3864 7879 2132 6033]
#  [   0    0    0 8028 3864 7879 2132 8301]
#  [   0    0    0 7600 3964 3987 9438  176]
#  [   0    0    0    0 6551 1419  170 2132]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
embedding_dim = globals().get('dim', 10)
model.add(Embedding(voc_size, embedding_dim, input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\SUJAY GADE\OneDrive\Desktop\DEEP LEARNING\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# build the model before calling summary
model.build(input_shape=(None, sent_length))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3964, 5039, 9438, 2955])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 91ms/step
# array([[ 3.7318733e-02,  1.1163820e-02, -1.0181271e-02, -4.2209055e-02,
#          3.3177435e-05, -3.2645367e-02,  3.7327599e-02, -4.0313948e-02,
#         -1.2005936e-02, -3.9044607e-02],
#        [ 3.7318733e-02,  1.1163820e-02, -1.0181271e-02, -4.2209055e-02,
#          3.3177435e-05, -3.2645367e-02,  3.7327599e-02, -4.0313948e-02,
#         -1.2005936e-02, -3.9044607e-02],
#        [ 3.7318733e-02,  1.1163820e-02, -1.0181271e-02, -4.2209055e-02,
#          3.3177435e-05, -3.2645367e-02,  3.7327599e-02, -4.0313948e-02,
#         -1.2005936e-02, -3.9044607e-02],
#        [ 3.7318733e-02,  1.1163820e-02, -1.0181271e-02, -4.2209055e-02,
#          3.3177435e-05, -3.2645367e-02,  3.7327599e-02, -4.0313948e-02,
#         -1.2005936e-02, -3.9044607e-02],
#        [ 4.1725960e-02,  1.5207980e-02,  4.3945756e-02,  4.5122616e-03,
#          4.9298182e-03,  2.1266453e-03, -3.3888541e-02,  2.4294887e-02,
#         -1.4841460e-02, -3.3659101e-02],
#        [-1.0599863e-02, -8.7428689e-03, -4.5732941e-02,  3.2353353e-02,
#          3.7094839e-03, -3.8880337e-02,  7.7088960e-03, -2.4943464e-03,
#          2.9104721e-02,  1.8596139e-02],
#        [-2.0161331e-02,  1.6732100e-02,  4.1258167e-02, -1.0361873e-02,
#          4.9908254e-02, -3.5579577e-03, -6.8925843e-03, -1.3193883e-02,
#          1.1708461e-02, -1.9058658e-02],
#        [ 9.7836629e-03, -4.7332238e-02, -2.9016364e-02, -4.2049907e-02,
#         -3.9179213e-03,  4.6187077e-02, -5.4925308e-03, -3.1149065e-02,
#          9.1638565e-03,  8.8497996e-03]], dtype=float32)
